# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import os

folder_path = r"C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data"

files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

dataframes = []

for file in files:
    path = os.path.join(folder_path, file)
    df = pd.read_csv(path, encoding='latin1')  
    dataframes.append(df)


# Merge all DataFrames into a single DataFrame
merged_df = pd.concat(dataframes, ignore_index=True)

# Display the merged DataFrame
merged_df
# Out:
#                             property_id  type   activation_date  bathroom  \
# 0      ff8080814a078fd2014a15c813ff0b03  BHK3  20-02-2017 09:24       3.0
# 1      ff8081814c2dea94014c50865ea35904  BHK2  11-03-2017 16:12       2.0
# 2      ff8081814cff7251014d04e2cc7018fd  BHK2  18-03-2017 14:26       2.0
# 3      ff8081814eb65997014ebbaa22f11869  BHK2  28-03-2017 11:09       2.0
# 4      ff8081814fa8748d014fabcabea10bb6  BHK3  14-02-2017 17:07       2.0
# ...                                 ...   ...               ...       ...
# 14527  ff8081815b15c304015b18b33e467d05  BHK3  29-03-2017 12:30       3.0
# 14528  ff8081815b15c304015b18f78f4e2503  BHK2  29-03-2017 13:18       2.0
# 14529  ff8081815b15c304015b1a4c67134ce4  BHK3  30-03-2017 14:10       1.0
# 14530  ff8081815b15c304015b1df97fb2695f  BHK3  30-03-2017 12:36       2.0
# 14531  ff8081815b1e0e51015b1e3ef2b51346  BHK2  30-03-2017 15:23       2.0
#
#        floor  total_floor      furnishing gym   latitude  longitude  ...  \
# ...

# %%
len(merged_df.columns.to_list())
# Out:
# 24

# %%
csv_files
# Out:
# ['Akshayanagar.csv',
#  'Arekere.csv',
#  'Banashankari.csv',
#  'Basavanagudi.csv',
#  'Basaveshwar Nagar.csv',
#  'Begur.csv',
#  'Bellandur.csv',
#  'Bilekahalli.csv',
#  'Bommanahalli.csv',
#  'Brookefield.csv',
#  'BTM 2nd Stage.csv',
#  'BTM_Layout.csv',
#  'Chikkalasandra.csv',
#  'Doddanekundi.csv',
#  'Ejipura.csv',
#  'Electronic City.csv',
#  'Electronics City Phase 1.csv',
#  'Gottigere.csv',
#  'HBR Layout.csv',
#  'Hebbal.csv',
#  'Hongasandra.csv',
#  'Hoodi.csv',
#  'Horamavu.csv',
#  'Hosakerehalli.csv',
#  'HSR_Layout.csv',
#  'Hulimavu.csv',
#  'Indiranagar.csv',
#  'Jayanagar.csv',
#  'JP Nagar.csv',
#  'K.R Puram.csv',
#  'Kadugodi.csv',
#  'Kaggadasapura.csv',
#  'Kalyan Nagar.csv',
#  'Kammanahalli.csv',
#  'Kasavanahalli.csv',
#  'Kengeri Satellite Town.csv',
#  'Kengeri.csv',
#  'Konanakunte.csv',
#  'Koramangala.csv',
#  'Krishnarajapura.csv',
#  'Kumaraswamy Layout.csv',
#  'Lingarajapuram.csv',
#  'Mahadevapura.csv',
#  'Marathahalli.csv',
# ...

# %%
df=pd.read_csv(r"C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Akshayanagar.csv")

# %%
df
# Out:
#                           property_id  type   activation_date  bathroom  \
# 0    ff8080814a078fd2014a15c813ff0b03  BHK3  20-02-2017 09:24         3
# 1    ff8081814c2dea94014c50865ea35904  BHK2  11-03-2017 16:12         2
# 2    ff8081814cff7251014d04e2cc7018fd  BHK2  18-03-2017 14:26         2
# 3    ff8081814eb65997014ebbaa22f11869  BHK2  28-03-2017 11:09         2
# 4    ff8081814fa8748d014fabcabea10bb6  BHK3  14-02-2017 17:07         2
# ..                                ...   ...               ...       ...
# 139  ff8081815af60983015af6372321123c  BHK2  22-03-2017 19:25         2
# 140  ff8081815b00b011015b03d8924e4761  BHK3  26-03-2017 08:43         2
# 141  ff8081815b05c610015b0935fd696894  BHK2  28-03-2017 12:12         2
# 142  ff8081815b0f1e48015b0f40f2380e38  BHK3  27-03-2017 19:49         2
# 143  ff8081815b106c7d015b194b18225ec6  BHK1  29-03-2017 15:34         1
#
#      floor  total_floor      furnishing  gym   latitude  longitude  ... lift  \
# ...

# %%
# Read each CSV file into a separate DataFrame
for file in csv_files:
    path = folder_path + '\\'+file
    print(path)
# Out:
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Akshayanagar.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Arekere.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Banashankari.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Basavanagudi.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Basaveshwar Nagar.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Begur.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Bellandur.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Bilekahalli.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Bommanahalli.csv
# C:\Users\91852\Downloads\Property_data-20250109T062142Z-001\Property_data\Brookefield.csv
# ...
